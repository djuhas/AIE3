# %% [markdown]
# # LangSmith and Evaluation Overview with AI Makerspace
#
# Today we'll be looking at an amazing tool:
#
# [LangSmith](https://docs.smith.langchain.com/)!
#
# This tool will help us monitor, test, debug, and evaluate our LangChain applications - and more!
#
# We'll also be looking at a few Advanced Retrieval techniques along the way - and evaluate it using LangSmith!
#
# ✋BREAKOUT ROOM #1:
# - Task 1: Dependencies and OpenAI API Key
# - Task 2: Basic RAG Chain
# - Task 3: Setting Up LangSmith
# - Task 4: Examining the Trace in LangSmith!
# - Task 5: Create Testing Dataset
#
# ✋BREAKOUT ROOM #2:
# - Task 1: Parent Document Retriever
# - Task 2: Ensemble Retriever

# %% [markdown]
# ## Task 1: Dependencies and OpenAI API Key
#
# We'll be using OpenAI's suite of models today to help us generate and embed our documents for a simple RAG system built on top of LangChain's blogs!

# %%
# !pip install langchain_core langchain_openai langchain_community langchain-qdrant qdrant-client langsmith openai tiktoken cohere -qU

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API Key:")

# %% [markdown]
# ## Task 2: Basic RAG Chain
#
# Now we'll set up our basic RAG chain, first up we need a model!

# %% [markdown]
# ### OpenAI Model
#
#
# We'll use OpenAI's `gpt-3.5-turbo` model to ensure we can use a stronger model for decent evaluation later!
#
# Notice that we can tag our resources - this will help us be able to keep track of which resources were used where later on!

# %%
from langchain_openai.chat_models import ChatOpenAI

base_llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    tags=["base_llm"]
)

# %% [markdown]
# #### Asyncio Bug Handling
#
# This is necessary for Colab.

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### SiteMap Loader
#
# We'll use a SiteMapLoader to scrape the LangChain blogs.

# %%
# need to install lxml
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages (5.2.2)

# %%
from langchain.document_loaders import SitemapLoader

documents = SitemapLoader(web_path="https://blog.langchain.dev/sitemap-posts.xml").load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Fetching pages: 100%|##########| 221/221 [00:07<00:00, 30.57it/s]

# %%
documents[0].metadata["source"]
# Out:
# 'https://blog.langchain.dev/what-is-an-agent/'

# %% [markdown]
# ### RecursiveCharacterTextSplitter
#
# We're going to use a relatively naive text splitting strategy today!

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

split_documents = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 500,
    chunk_overlap = 20
).split_documents(documents)

# %%
len(split_documents)
# Out:
# 1548

# %% [markdown]
# ### Embeddings
#
# We'll be leveraging OpenAI's [text-embedding-3-small](https://openai.com/index/new-embedding-models-and-api-updates/) today!

# %%
from langchain_openai.embeddings import OpenAIEmbeddings

base_embeddings_model = OpenAIEmbeddings(model="text-embedding-3-small")

# %% [markdown]
# ### Qdrant VectorStore Retriever
#
# Now we can use a Qdrant VectorStore to embed and store our documents and then convert it to a retriever so it can be used in our chain!

# %%
from langchain_qdrant import Qdrant

vectorstore = Qdrant.from_documents(
    split_documents,
    base_embeddings_model,
    location=":memory:",
    collection_name="langchainblogs")

# %%
base_retriever = vectorstore.as_retriever()

# %% [markdown]
# ### Prompt Template
#
# All we have left is a prompt template, which we'll create here!

# %%
from langchain.prompts import ChatPromptTemplate

base_rag_prompt_template = """\
Using the provided context, please answer the user's question. If you don't know the answer based on the context, say you don't know.

Context:
{context}

Question:
{question}
"""

base_rag_prompt = ChatPromptTemplate.from_template(base_rag_prompt_template)

# %% [markdown]
# ### LCEL Chain
#
# Now that we have:
#
# - Embeddings Model
# - Generation Model
# - Retriever
# - Prompt
#
# We're ready to build our LCEL chain!
#
# Keep in mind that we're returning our source documents with our queries - while this isn't necessary, it's a great thing to get into the habit of doing.

# %%
from operator import itemgetter
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from langchain.schema import StrOutputParser

base_rag_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | base_retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": base_rag_prompt | base_llm | StrOutputParser(), "context": itemgetter("context")}
)

# %% [markdown]
# Let's test it out!

# %%
base_rag_chain.invoke({"question" : "What is a good way to evaluate agents?"})["response"]
# Out:
# "A good way to evaluate agents is by testing their capabilities in common agentic workflows, such as planning/task decomposition, function calling, and the ability to override pre-trained biases when needed. Additionally, evaluating the system's performance across different tasks and considering the model quality and service reliability are important aspects of evaluating agents."

# %% [markdown]
# ## Task 3: Setting Up LangSmith
#
# Now that we have a chain - we're ready to get started with LangSmith!
#
# We're going to go ahead and use the following `env` variables to get our Colab notebook set up to start reporting.
#
# If all you needed was simple monitoring - this is all you would need to do!

# %%
from uuid import uuid4

unique_id = uuid4().hex[0:8]

os.environ["LANGCHAIN_TRACING_V8"] = "true"
os.environ["LANGCHAIN_PROJECT"] = f"LangSmith - {unique_id}"

# %% [markdown]
# ### LangSmith API
#
# In order to use LangSmith - you will need a beta key, you can join the queue through the `Beta Sign Up` button on LangSmith's homepage!
#
# Join [here](https://www.langchain.com/langsmith)

# %%
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass('Enter your LangSmith API key: ')

# %% [markdown]
# Let's test our our first generation!

# %%
base_rag_chain.invoke({"question" : "What is LangSmith?"}, {"tags" : ["Demo Run"]})['response']
# Out:
# 'LangSmith is a unified platform for debugging, testing, evaluating, and monitoring LLM applications. It allows users to automate feedback loops, improve iteration speed, collaborate, and organize workspaces. LangSmith also offers features like utilizing existing datasets, creating new datasets, running them against chains, providing visual feedback on outputs, accuracy metrics, and real-time monitoring.'

# %% [markdown]
# ## Task 4: Examining the Trace in LangSmith!
#
# Head on over to your LangSmith web UI to check out how the trace looks in LangSmith!

# %% [markdown]
# #### 🏗️ Activity #1:
#
# Include a screenshot of your trace and explain what it means.

# %% [markdown]
# ![image]()

# %% [markdown]
# ## Task 5: Create Testing Dataset
#
# Now we can create a dataset using some user defined questions, and providing the retrieved context as a "ground truth" context.
#
# > NOTE: There are many different ways you can approach this specific task - generating ground truth answers with AI, using human experts to generate golden datasets, and more!

# %% [markdown]
# ### Synthetic Data Generation (SDG)
#
# In order to full test our RAG chain, and the various modifications we'll be using in the following notebook, we'll need to create a small synthetic dataset that is relevant to our task!
#
# Let's start by generating a series of questions - which begins with a simple model definition!
#
# > NOTE: We're going to be using a purposefully simplified datagen pipeline as an example today - but you could leverage the RAGAS SDG pipeline just as easily.

# %%
question_model = ChatOpenAI(model="gpt-3.5-turbo")

# %% [markdown]
# Next up, we'll create some novel chunks from our source data!

# %%
sdg_documents = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 1000,
    chunk_overlap = 20
).split_documents(documents)

# %% [markdown]
# Now, let's ask some questions that could be answered from the provided chunks!

# %%
question_prompt_template = """\
You are a University Professor creating questions for an exam. You must create a question for a given piece of context.

The question must be answerable only using the provided context.

Avoid creating questions that are ambiguous or vague. They should be specifically related to the context.

Your output must only be the question.

Context:
{context}
"""

question_prompt = ChatPromptTemplate.from_template(question_prompt_template)

# %%
question_chain = question_prompt | question_model

# %% [markdown]
# Now we can loop through a subset of our context chunks and create question/context pairs!

# %%
from tqdm import tqdm
import json

question_context_pairs = []

for idx in tqdm(range(0, len(sdg_documents), 40)):
  question = question_chain.invoke({"context" : sdg_documents[idx].page_content})
  question_context_pairs.append({"question" : question.content, "context" : sdg_documents[idx].page_content, "idx" : idx})
# Out:
# 100%|██████████| 23/23 [00:17<00:00,  1.35it/s]

# %%
question_context_pairs[0]
# Out:
# {'question': 'Based on the provided context, what is the focus of the new series of musings introduced by Harrison Chase?',
#  'context': 'What is an agent?\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAll Posts\n\n\n\n\nRelease Notes\n\n\n\n\nCase Studies\n\n\n\n\nIn the Loop\n\n\n\n\nLangChain\n\n\n\n\nDocs\n\n\n\n\n\nSign in\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWhat is an agent?\nIntroducing a new series of musings on AI agents.\n\nHarrison Chase\n4 min read\nJun 28, 2024',
#  'idx': 0}

# %% [markdown]
# We'll repeat this process for answers!

# %%
answer_prompt_template = """\
You are a University Professor creating an exam. You must create a answer for a given piece of context and question.

The answer must only rely on the provided context.

Your output must only be the answer.

Context:
{context}
"""

answer_prompt = ChatPromptTemplate.from_template(answer_prompt_template)

# %%
answer_chain = answer_prompt | question_model

# %%
for question_context_pair in tqdm(question_context_pairs):
  question_context_pair["answer"] = answer_chain.invoke({"question" : question_context_pair["question"], "context" : question_context_pair["context"]}).content
# Out:
# 100%|██████████| 23/23 [00:15<00:00,  1.47it/s]

# %%
question_context_pairs[0]
# Out:
# {'question': 'Based on the provided context, what is the focus of the new series of musings introduced by Harrison Chase?',
#  'context': 'What is an agent?\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAll Posts\n\n\n\n\nRelease Notes\n\n\n\n\nCase Studies\n\n\n\n\nIn the Loop\n\n\n\n\nLangChain\n\n\n\n\nDocs\n\n\n\n\n\nSign in\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWhat is an agent?\nIntroducing a new series of musings on AI agents.\n\nHarrison Chase\n4 min read\nJun 28, 2024',
#  'idx': 0,
#  'answer': 'An agent is a program or entity that acts autonomously in an environment to achieve specified goals.'}

# %% [markdown]
# im not sure that did i needed to "add" something additional here?

# %% [markdown]
# Now we can set up our LangSmith client - and we'll add the above created dataset to our LangSmith instance!
#
# > NOTE: Read more about this process [here](https://docs.smith.langchain.com/old/evaluation/faq/manage-datasets#create-from-list-of-values)

# %%
from langsmith import Client

client = Client()

dataset_name = "langsmith-demo-dataset-v8"

dataset = client.create_dataset(
    dataset_name=dataset_name, description="LangChain Blog Test Questions"
)

for triplet in question_context_pairs:
  client.create_example(
      inputs={"question" : triplet["question"]},
      outputs={"answer" : triplet["answer"]},
      dataset_id=dataset.id
  )

# %% [markdown]
# ### Evaluation
#
# Now we can run the evaluation!
#
# We'll need to start by preparing some custom data preparation functions to ensure our chain works with the expected inputs/outputs from the `evaluate` process in LangSmith.
#
# > NOTE: More reading on this available [here](https://docs.smith.langchain.com/how_to_guides/evaluation/evaluate_llm_application#evaluate-a-langchain-runnable)

# %%
def prepare_data_ref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "reference" : example.outputs["answer"],
      "input" : example.inputs["question"]
  }

def prepare_data_noref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "input" : example.inputs["question"]
  }

# %% [markdown]
# We'll be using a few custom evaluators to evaluate our pipeline, as well as a few "built in" methods!
#
# Check out the built-ins [here](https://docs.smith.langchain.com/reference/sdk_reference/langchain_evaluators)!

# %%
from langsmith.evaluation import LangChainStringEvaluator, evaluate

eval_llm = ChatOpenAI(temperature=0.0, 
                      model="gpt-3.5-turbo",
                      timeout=600,
                      max_retries=2,
                     )

cot_qa_evaluator = LangChainStringEvaluator("cot_qa", prepare_data=prepare_data_ref, config={"llm": eval_llm})

unlabeled_dopeness_evaluator = LangChainStringEvaluator(
    "criteria",
    config={
        "criteria" : {
            "dopeness" : "Is the answer to the question dope, meaning cool - awesome - and legit?"
        },
        "llm": eval_llm,
    },
    prepare_data=prepare_data_noref
)

labeled_score_evaluator = LangChainStringEvaluator(
    "labeled_score_string",
    config={
        "criteria": {
            "accuracy": "Is the generated answer the same as the reference answer?"
        },
        "llm": eval_llm
    },
    prepare_data=prepare_data_ref
)

unlabeled_coherence_evaluator = LangChainStringEvaluator("criteria", 
                                                         config={
                                                             "criteria": "coherence",
                                                             "llm": eval_llm
                                                         }, 
                                                         prepare_data=prepare_data_noref,
                                                        )
labeled_relevance_evaluator = LangChainStringEvaluator("labeled_criteria", 
                                                       config={ 
                                                           "criteria": "relevance",
                                                           "llm": eval_llm
                                                        }, 
                                                       prepare_data=prepare_data_ref
                                                      )
base_rag_results = evaluate(
    base_rag_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        #unlabeled_dopeness_evaluator,
        #labeled_score_evaluator,
        #unlabeled_coherence_evaluator,  ## Removing some evaluators to avoid rate limits
        #labeled_relevance_evaluator
        ],
    experiment_prefix="Base RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Base RAG Evaluation-6e61486a' at:
# https://smith.langchain.com/o/992c905e-c795-5ddd-8a3e-d3218d33b426/datasets/3786e1c2-0d44-4245-b773-a7a73419a1d9/compare?selectedSessions=8f3cbb04-cd9b-4845-87aa-94286c2597b5
# 0it [00:00, ?it/s]Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59778, Requested 2190. Please try again in 1.968s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59755, Requested 1772. Please try again in 1.527s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59652, Requested 1964. Please try again in 1.616s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59514, Requested 2064. Please try again in 1.578s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59332, Requested 2201. Please try again in 1.533s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59007, Requested 2587. Please try again in 1.594s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 179f13f0-bcfc-41b1-8ec5-06b23dbe5d49: KeyError('response')
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_95661/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# 1it [00:05,  5.68s/it]Error running evaluator <DynamicRunEvaluator evaluate> on run bc125fe7-af49-49c9-b36f-e8e67a1e277f: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59831, Requested 320. Please try again in 151ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 307, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59831, Requested 320. Please try again in 151ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 2it [00:06,  2.85s/it]Error running evaluator <DynamicRunEvaluator evaluate> on run fa32dc3d-88c7-4bef-82ec-9de95db28c4a: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59821, Requested 336. Please try again in 157ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 307, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59821, Requested 336. Please try again in 157ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run b6b6181f-38dd-4cb2-bf01-28f137fa31f2: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59816, Requested 337. Please try again in 153ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 307, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59816, Requested 337. Please try again in 153ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run db1d51aa-9884-4f34-b7e0-9ccf6afc5722: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59794, Requested 368. Please try again in 162ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 307, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59794, Requested 368. Please try again in 162ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 9e690d22-0cc1-48b5-b88b-dbb51101b9b9: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59787, Requested 357. Please try again in 144ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 307, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59787, Requested 357. Please try again in 144ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run f26e1a1c-33fc-4aee-8ba6-3559496a5c42: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59780, Requested 375. Please try again in 155ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 307, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59780, Requested 375. Please try again in 155ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 6871db74-819a-442f-8939-4142457865e8: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59756, Requested 364. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 307, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59762, Requested 382. Please try again in 144ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 15aa583a-9919-4f83-b03e-80d8fe71de19: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59736, Requested 423. Please try again in 159ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/evaluation/qa/eval_chain.py", line 307, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 60000, Used 59736, Requested 423. Please try again in 159ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 0b8b8438-b3c6-45bd-9522-01407a0f04dd: KeyError('response')
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_95661/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# 11it [00:06,  2.86it/s]Error running evaluator <DynamicRunEvaluator evaluate> on run bfe7034c-0c51-4fd6-b450-ff0df724a1ed: KeyError('response')
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_95661/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run 1fbbe456-2245-4076-8acc-d10a3c4e586b: KeyError('response')
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_95661/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run f7529273-3aea-4372-a909-25aceec0081b: KeyError('response')
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_95661/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# Error running evaluator <DynamicRunEvaluator evaluate> on run c836c4b8-a9ae-4b75-ad9c-fe91482b0b0d: KeyError('response')
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_95661/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# 23it [00:09,  2.54it/s]

# %% [markdown]
# ## Testing Other Retrievers
#
# Now we can test our how changing our Retriever impacts our LangSmith evaluation!
#
# We'll build this simple qa_chain factory to create standardized qa_chains where the only different component will be the retriever.

# %%
def create_qa_chain(retriever):
  primary_qa_llm = ChatOpenAI(model_name="gpt-4o", temperature=0)
  created_qa_chain = (
    {"context": itemgetter("question") | retriever,
     "question": itemgetter("question")
    }
    | RunnablePassthrough.assign(
        context=itemgetter("context")
      )
    | {
         "response": base_rag_prompt | primary_qa_llm,
         "context": itemgetter("context"),
      }
  )
  return created_qa_chain

# %% [markdown]
# ### Task 1: Parent Document Retriever
#
# One of the easier ways we can imagine improving a retriever is to embed our documents into small chunks, and then retrieve a significant amount of additional context that "surrounds" the found context.
#
# You can read more about this method [here](https://python.langchain.com/docs/modules/data_connection/retrievers/parent_document_retriever)!
#
# The basic outline of this retrieval method is as follows:
#
# 1. Obtain User Question
# 2. Retrieve child documents using Dense Vector Retrieval
# 3. Merge the child documents based on their parents. If they have the same parents - they become merged.
# 4. Replace the child documents with their respective parent documents from an in-memory-store.
# 5. Use the parent documents to augment generation.

# %%
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams

client = QdrantClient(":memory:")
client.create_collection(
    collection_name="split_parents",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)

vectorstore = Qdrant(client, collection_name="split_parents", embeddings=base_embeddings_model)

store = InMemoryStore()

# %%
parent_document_retriever = ParentDocumentRetriever(
    vectorstore=vectorstore,
    docstore=store,
    child_splitter=RecursiveCharacterTextSplitter(chunk_size=400),
    parent_splitter=RecursiveCharacterTextSplitter(chunk_size=2000),
)

# %%
parent_document_retriever.add_documents(documents)

# %% [markdown]
# Let's create, test, and then evaluate our new chain!

# %%
parent_document_retriever_qa_chain = create_qa_chain(parent_document_retriever)

# %%
parent_document_retriever_qa_chain.invoke({"question" : "What is RAG?"})["response"].content
# Out:
# 'RAG, or Retrieval Augmented Generation, is a central paradigm in LLM (Large Language Model) application development. It addresses the limitation that most LLMs are only periodically trained on a large corpus of public data, which means they lack recent information and/or private data that is inaccessible for training. The basic RAG pipeline involves embedding a user query, retrieving relevant documents to the query, and passing the documents to an LLM for the generation of an answer grounded in the retrieved context.'

# %% [markdown]
# #### Evaluating the Parent Document Retrieval Pipeline
#
# Now that we've created a new retriever - let's try evaluating it on the same dataset!

# %%
pdr_rag_results = evaluate(
    parent_document_retriever_qa_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator
        #unlabeled_dopeness_evaluator,
        #labeled_score_evaluator,
        #unlabeled_coherence_evaluator,
        #labeled_relevance_evaluator
        ],
    experiment_prefix="Parent Document Retrieval RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Parent Document Retrieval RAG Evaluation-43efd0d7' at:
# https://smith.langchain.com/o/992c905e-c795-5ddd-8a3e-d3218d33b426/datasets/3786e1c2-0d44-4245-b773-a7a73419a1d9/compare?selectedSessions=00916382-8651-4974-8c20-8254a3354edf
# 0it [00:00, ?it/s]Error running target function: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-C5zGtTjCpndhjcagtxrQt8Ni on tokens per min (TPM): Limit 30000, Used 29225, Requested 1545. Please try again in 1.54s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# 6it [00:11,  1.28it/s]Error running evaluator <DynamicRunEvaluator evaluate> on run cecc0167-9528-4e42-8bce-d59336fbfd36: KeyError('response')
# Traceback (most recent call last):
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/djuhas/anaconda3/envs/aie3week5d1/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 255, in evaluate
#     else self._prepare_data(run, example)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_95661/3523963876.py", line 3, in prepare_data_ref
#     "prediction" : run.outputs["response"],
#                    ~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'response'
# 23it [00:14,  1.58it/s]

# %% [markdown]
# ### Task 2: Ensemble Retrieval
#
# Next let's look at ensemble retrieval!
#
# You can read more about this [here](https://python.langchain.com/docs/modules/data_connection/retrievers/ensemble)!
#
# The basic idea is as follows:
#
# 1. Obtain User Question
# 2. Hit the Retriever Pair
#     - Retrieve Documents with BM25 Sparse Vector Retrieval
#     - Retrieve Documents with Dense Vector Retrieval Method
# 3. Collect and "fuse" the retrieved docs based on their weighting using the [Reciprocal Rank Fusion](https://plg.uwaterloo.ca/~gvcormac/cormacksigir09-rrf.pdf) algorithm into a single ranked list.
# 4. Use those documents to augment our generation.
#
# Ensure your `weights` list - the relative weighting of each retriever - sums to 1!

# %%
# !pip install -q -U rank_bm25

# %%
from langchain.retrievers import BM25Retriever, EnsembleRetriever

text_splitter = RecursiveCharacterTextSplitter(chunk_size=450, chunk_overlap=75)
split_documents = text_splitter.split_documents(documents)

bm25_retriever = BM25Retriever.from_documents(split_documents)
bm25_retriever.k = 2

embedding = OpenAIEmbeddings()
vectorstore = Qdrant.from_documents(split_documents, embedding, location=":memory:")
qdrant_retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

ensemble_retriever = EnsembleRetriever(
    retrievers=[
        bm25_retriever,
        qdrant_retriever
    ],
    weights=[
        0.5,
        0.5
    ])

# %%
ensemble_retriever_qa_chain = create_qa_chain(ensemble_retriever)

# %%
ensemble_retriever_qa_chain.invoke({"question" : "What is RAG?"})["response"].content
# Out:
# 'RAG stands for Retrieval Augmented Generation. It is a central paradigm in LLM (Large Language Model) application development that addresses the limitation of LLMs, which are only periodically trained on a large corpus of public data and thus lack recent information or private data that is inaccessible for training. RAG connects LLMs to external data sources to enhance their performance and provide more accurate and up-to-date information.'

# %%
pdr_rag_results = evaluate(
    ensemble_retriever_qa_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator
        #unlabeled_dopeness_evaluator,
        #labeled_score_evaluator,
        #unlabeled_coherence_evaluator,
        #labeled_relevance_evaluator
        ],
    experiment_prefix="Hybrid Retrieval RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Hybrid Retrieval RAG Evaluation-45fd25b0' at:
# https://smith.langchain.com/o/992c905e-c795-5ddd-8a3e-d3218d33b426/datasets/3786e1c2-0d44-4245-b773-a7a73419a1d9/compare?selectedSessions=9663b46b-2425-412f-8b92-a4f539cc25a0
# 23it [00:14,  1.61it/s]

# %% [markdown]
# #### ❓Question #1:
#
# What conclusions can you draw about the above results?
#
# Describe in your own words what the metrics are expressing.

# %% [markdown]
# #### Answer #1:
#
# after fail-ing so many times (reaching GPT limit) i finaly made it to the end (but only with cot_qa_evaluator). give me some credits for trying to solve this
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
